# %%
# Bibliotheken installieren (falls noch nicht vorhanden)
# !pip install yfinance pandas matplotlib

# Notwendige Bibliotheken importieren
import yfinance as yf         # Bibliothek für Yahoo Finance Daten4
import pandas as pd          # Datenanalyse und -bearbeitung5
import matplotlib.pyplot as plt  # Visualisierung
from datetime import datetime   # Datum und Uhrzeit-Funktionen

# Hinweis: yfinance stellt kostenlos historische Marktdaten über Yahoo Finance bereit67.
# Out:
# Requirement already satisfied: yfinance in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\besitzer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\Besitzer\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# Zeitpunkt berechnen: heute und vor 6 Monaten
heute = pd.Timestamp.today()                 # aktuelles Datum und Uhrzeit
start_date = heute - pd.DateOffset(months=6) # genau 6 Monate zurück
start_str = start_date.strftime("%Y-%m-%d")  # Formatieren als "YYYY-MM-DD"
end_str = heute.strftime("%Y-%m-%d")

print(f"Zeitraum: {start_str} bis {end_str}")

# %%
# Historische Kursdaten abrufen
# Wir laden die täglichen Schlusskurse (Close) der letzten 6 Monate
ticker_nvda = "NVDA"
ticker_tsla = "TSLA"

# Daten für NVDA herunterladen (OHLCV: Open, High, Low, Close, Volume)
df_nvda = yf.download(ticker_nvda,
                      start=start_str,
                      end=end_str,
                      interval="1d",
                      progress=False)

# Daten für TSLA herunterladen
df_tsla = yf.download(ticker_tsla,
                      start=start_str,
                      end=end_str,
                      interval="1d",
                      progress=False)

# Überprüfung: Zeige jeweils die ersten Zeilen
print(df_nvda.head(3))
print(df_tsla.head(3))

# %%
# Nur die Schlusskurse behalten und Spalte umbenennen
df_nvda = df_nvda[["Close"]].rename(columns={"Close": "Schlusskurs"})
df_tsla = df_tsla[["Close"]].rename(columns={"Close": "Schlusskurs"})

# Datumsindex umbenennen (optional, für Klarheit)
df_nvda.index.name = "Datum"
df_tsla.index.name = "Datum"

# Ausgabe der bereinigten DataFrames
display(df_nvda.head(3))
display(df_tsla.head(3))

# %%
# (Optional) Daten exportieren
# Als CSV-Dateien speichern
df_nvda.to_csv("NVDA_schlusskurse.csv", index=True)
df_tsla.to_csv("TSLA_schlusskurse.csv", index=True)

# Als JSON-Dateien speichern (Datum im ISO-Format)
df_nvda.to_json("NVDA_schlusskurse.json", orient="records", date_format="iso")
df_tsla.to_json("TSLA_schlusskurse.json", orient="records", date_format="iso")

# %%
# (Optional) Visualisierung der Kursentwicklung
plt.figure(figsize=(10, 6))
plt.plot(df_nvda.index, df_nvda["Schlusskurs"], label="NVDA")
plt.plot(df_tsla.index, df_tsla["Schlusskurs"], label="TSLA")
plt.title("Schlusskurse NVDA und TSLA (letzte 6 Monate)")
plt.xlabel("Datum")
plt.ylabel("Schlusskurs (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
